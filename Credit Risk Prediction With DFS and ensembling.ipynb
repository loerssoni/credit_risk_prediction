# %% [markdown]
# # Deep feature synthesis

# %% [markdown]
# We first generate two data sets, a monthly set of transactions and a set of static data for the loans.
#
# The final dataset will consist of features automatically engineered from these datasets.
# We run three different transformations: addition, multiplication and division for the loans data for different aggregations of the monthly transactions data.
# Each of these aggregation operations results in a large amount of generated features. We will then run a process of selecting variables.

# %%
import featuretools as ft
import pandas as pd
import pickle

# %%
# !python dfs_prep.py
# Out:
# sys:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
with open('dfs_data_loans', 'rb') as file:
    loans = pickle.load(file, encoding="latin1")

with open('dfs_data_trans', 'rb') as file:
    trans = pickle.load(file, encoding="latin1")

# %%
y = loans.target
loans_x = loans.drop('target', axis=1)
trans.reset_index(inplace=True)
trans
# Out:
#       index  loan_id  month  amount_trans_sum  amount_trans_mean  \
# 0         0     4959  23918            2200.0        1100.000000
# 1         1     4959  23919           47899.0        7983.166667
# 2         2     4959  23920           62691.0       10448.500000
# 3         3     4959  23921           75961.4       12660.233333
# 4         4     4959  23922          105827.8       17637.966667
# ...     ...      ...    ...               ...                ...
# 9426   9426     7308  23960           34251.2        3805.688889
# 9427   9427     7308  23961           31309.4        3913.675000
# 9428   9428     7308  23962           29102.8        3233.644444
# 9429   9429     7308  23963           29730.3        3716.287500
# 9430   9430     7308  23964           46267.0        5783.375000
#
#       amount_trans_max  amount_trans_min  balance_sum  balance_mean  \
# 0               1100.0            1100.0       2200.0   1100.000000
# 1              20236.0              13.5     142843.0  23807.166667
# 2              20236.0             109.5     227931.8  37988.633333
# 3              20236.0             144.7     257674.8  42945.800000
# 4              30354.0             159.9     315897.4  52649.566667
# ...                ...               ...          ...           ...
# 9426           16141.0              56.0     206105.1  22900.566667
# 9427           16141.0              56.0     195245.5  24405.687500
# 9428           16141.0              56.0     242661.2  26962.355556
# 9429           16141.0              56.0     200993.7  25124.212500
# 9430           24212.0              56.0     257617.0  32202.125000
#
#       balance_max  ...  interest_max  interest_min  c_deposit_sum  \
# 0          1100.0  ...             0             0              2
# 1         25049.5  ...             1             0              2
# 2         45285.5  ...             1             0              0
# 3         54630.9  ...             1             0              0
# 4         67529.6  ...             1             0              0
# ...           ...  ...           ...           ...            ...
# 9426      30208.2  ...             1             0              1
# 9427      31014.9  ...             1             0              1
# 9428      32119.6  ...             1             0              1
# 9429      30857.8  ...             1             0              1
# 9430      45294.5  ...             0             0              1
#
#       c_deposit_mean  c_deposit_max  c_deposit_min  c_withdr_sum  \
# 0           1.000000              1              1             0
# 1           0.333333              1              0             0
# 2           0.000000              0              0             2
# 3           0.000000              0              0             2
# 4           0.000000              0              0             2
# ...              ...            ...            ...           ...
# 9426        0.111111              1              0             3
# 9427        0.125000              1              0             2
# 9428        0.111111              1              0             3
# 9429        0.125000              1              0             2
# 9430        0.125000              1              0             3
#
#       c_withdr_mean  c_withdr_max  c_withdr_min
# 0          0.000000             0             0
# 1          0.000000             0             0
# 2          0.333333             1             0
# 3          0.333333             1             0
# 4          0.333333             1             0
# ...             ...           ...           ...
# 9426       0.333333             1             0
# 9427       0.250000             1             0
# 9428       0.333333             1             0
# 9429       0.250000             1             0
# 9430       0.375000             1             0
#
# [9431 rows x 43 columns]

# %% [markdown]
# ### Create entityset, generate features

# %%
es = ft.EntitySet(id = 'loan')
es.entity_from_dataframe(entity_id = 'loan', dataframe = loans_x, index='loan_id')
es.entity_from_dataframe(entity_id='trans',
                                 dataframe=trans,
                                 index='index',
                                 time_index='month')
rl = ft.Relationship(es['loan']['loan_id'],
                                    es['trans']['loan_id'])

# Add the relationship to the entity set
es = es.add_relationship(rl)

# %%
mult_feature_matrix, _ = ft.dfs(entityset=es,
                       target_entity = 'loan',
                       agg_primitives = ['min','mean','max'],
                       trans_primitives = ['multiply_numeric'],
                       max_depth = 2, 
                       verbose = 1, 
                       n_jobs = -1)
# Out:
# Built 12900 features
#
# Elapsed: 00:00 | Progress:   0%|
#
# EntitySet scattered to 2 workers in 5 seconds
# Elapsed: 00:27 | Progress:   0%|
# Elapsed: 00:00 | Progress:   0%|
# Elapsed: 00:52 | Progress:  48%|█████████████████████████████████████████▎
# Elapsed: 00:53 | Progress:  95%|██████████████████████████████████████████████████████████████████████████████████▋
# Elapsed: 00:57 | Progress: 100%|███████████████████████████████████████████████████████████████████████████████████████
# Elapsed: 00:57 | Progress: 100%|███████████████████████████████████████████████████████████████████████████████████████

# %%
mult_feature_matrix = mult_feature_matrix.loc[:,(mult_feature_matrix.isna().sum() == 0)]
mult_feature_matrix = mult_feature_matrix.loc[:,(mult_feature_matrix.var() > 0)]
mult_feature_matrix
# Out:
#            amount  duration  payments         A4     A5    A6    A7   A8   A9  \
# loan_id
# 4959      80952.0      24.0    3373.0  1204953.0    0.0   0.0   0.0  1.0  1.0
# 4961      30276.0      12.0    2523.0   103347.0   87.0  16.0   7.0  1.0  7.0
# 4962      30276.0      12.0    2523.0   228848.0   15.0  40.0  18.0  2.0  6.0
# 4967     318480.0      60.0    5308.0    70646.0   94.0  14.0   3.0  1.0  4.0
# 4968     110736.0      48.0    2307.0    51428.0   50.0  11.0   3.0  1.0  4.0
# ...           ...       ...       ...        ...    ...   ...   ...  ...  ...
# 7294      39168.0      24.0    1632.0    94725.0   38.0  28.0   1.0  3.0  6.0
# 7295     280440.0      60.0    4674.0   387570.0    0.0   0.0   0.0  1.0  1.0
# 7304     419880.0      60.0    6998.0  1204953.0    0.0   0.0   0.0  1.0  1.0
# 7305      54024.0      12.0    4502.0   117897.0  139.0  28.0   5.0  1.0  6.0
# 7308     129408.0      24.0    5392.0   106054.0   38.0  25.0   6.0  2.0  6.0
#
#            A10  ...  MAX(trans.c_withdr_max) * MEAN(trans.b_withdr_mean)  \
# loan_id         ...
# 4959     100.0  ...                                           0.000000
# 4961      67.0  ...                                           0.000000
# 4962      57.2  ...                                           0.111655
# 4967      58.4  ...                                           0.105849
# 4968      52.7  ...                                           0.076058
# ...        ...  ...                                                ...
# 7294      63.4  ...                                           0.000000
# 7295     100.0  ...                                           0.000000
# 7304     100.0  ...                                           0.000000
# 7305      53.8  ...                                           0.118851
# 7308      63.1  ...                                           0.157778
#
#          MEAN(trans.b_deposit_sum) * MEAN(trans.hhold_mean)  \
# loan_id
# 4959                                              0.141873
# 4961                                              0.098901
# 4962                                              0.000000
# 4967                                              0.000000
# 4968                                              0.057540
# ...                                                    ...
# 7294                                              0.000000
# 7295                                              0.000000
# 7304                                              0.055556
# 7305                                              0.118851
# 7308                                              0.000000
#
#          MAX(trans.b_withdr_sum) * MEAN(trans.balance_sum)  \
# loan_id
# 4959                                              0.000000
# 4961                                              0.000000
# 4962                                         531748.022222
# 4967                                         282637.973333
# 4968                                         177773.300000
# ...                                                    ...
# 7294                                              0.000000
# 7295                                              0.000000
# 7304                                              0.000000
# 7305                                         214978.309091
# 7308                                         414407.493333
#
#          MEAN(trans.balance_min) * payments  \
# loan_id
# 4959                           8.348865e+07
# 4961                           4.094421e+07
# 4962                           8.815989e+07
# 4967                           1.244936e+08
# 4968                           5.506504e+07
# ...                                     ...
# 7294                           6.837736e+07
# 7295                           1.202509e+08
# 7304                           3.014256e+08
# 7305                           1.272831e+08
# 7308                           1.207869e+08
#
#          MEAN(trans.interest_max) * MIN(trans.amount_trans_min)  \
# loan_id
# 4959                                             12.272727
# 4961                                             43.476923
# 4962                                            112.333333
# 4967                                              0.373333
# 4968                                             42.844444
# ...                                                    ...
# 7294                                             41.166667
# 7295                                             58.176190
# 7304                                             26.000000
# 7305                                             67.300000
# 7308                                             43.420000
#
#          accnt_age * MIN(trans.interest_max)  \
# loan_id
# 4959                                0.000000
# 4961                                0.000000
# 4962                                0.000000
# 4967                                0.000000
# 4968                                0.000000
# ...                                      ...
# 7294                                0.000000
# 7295                                0.000000
# 7304                                0.000000
# 7305                                1.848049
# 7308                                0.000000
#
#          MAX(trans.hhold_max) * MEAN(trans.insur_max)  \
# loan_id
# 4959                                         0.000000
# 4961                                         0.000000
# 4962                                         0.777778
# 4967                                         0.800000
# 4968                                         0.444444
# ...                                               ...
# 7294                                         0.000000
# 7295                                         0.000000
# 7304                                         0.000000
# 7305                                         0.000000
# 7308                                         0.666667
#
#          MEAN(trans.hhold_sum) * MIN(trans.c_withdr_mean)  \
# loan_id
# 4959                                             0.000000
# 4961                                             0.000000
# 4962                                             0.000000
# 4967                                             0.000000
# 4968                                             0.000000
# ...                                                   ...
# 7294                                             0.000000
# 7295                                             0.000000
# 7304                                             0.000000
# 7305                                             0.193182
# 7308                                             0.000000
#
#          MAX(trans.amount_trans_mean) * MIN(trans.c_deposit_max)  \
# loan_id
# 4959                                              0.000000
# 4961                                              0.000000
# 4962                                              0.000000
# 4967                                              0.000000
# 4968                                              0.000000
# ...                                                    ...
# 7294                                          14086.466667
# 7295                                              0.000000
# 7304                                              0.000000
# 7305                                              0.000000
# 7308                                          11111.500000
#
#          A7 * MEAN(trans.c_deposit_sum)
# loan_id
# 4959                           0.000000
# 4961                           4.846154
# 4962                          36.000000
# 4967                           3.600000
# 4968                           2.000000
# ...                                 ...
# 7294                           1.083333
# 7295                           0.000000
# 7304                           0.000000
# 7305                           0.227273
# 7308                           6.400000
#
# [682 rows x 8384 columns]

# %%
div_feature_matrix, _ = ft.dfs(entityset=es,
                       target_entity = 'loan',
                       agg_primitives = ['mean'],
                       trans_primitives = ['divide_numeric'],
                       max_depth = 2, 
                       verbose = 1, 
                       n_jobs = -1)
# Out:
# Built 5484 features
#
# Elapsed: 00:00 | Progress:   0%|
# C:\Users\lheikka\AppData\Roaming\Python\Python37\site-packages\featuretools\computational_backends\utils.py:147: UserWarning: 3 workers requested, but only 2 workers created.
#   warnings.warn(warning_string)
#
# EntitySet scattered to 2 workers in 5 seconds
# Elapsed: 04:12 | Progress:   0%|
# Elapsed: 00:00 | Progress:   0%|
# Elapsed: 00:20 | Progress:  48%|█████████████████████████████████████████▎
# Elapsed: 00:21 | Progress:  95%|██████████████████████████████████████████████████████████████████████████████████▋
# Elapsed: 00:23 | Progress: 100%|███████████████████████████████████████████████████████████████████████████████████████
# Elapsed: 00:23 | Progress: 100%|███████████████████████████████████████████████████████████████████████████████████████

# %%
div_feature_matrix = div_feature_matrix.loc[:,(div_feature_matrix.isna().sum() == 0)]
div_feature_matrix = div_feature_matrix.loc[:,(div_feature_matrix.var() > 0)]
dive_feature_matrix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-7a9933e47156> in <module>
#       1 div_feature_matrix = div_feature_matrix.loc[:,(div_feature_matrix.isna().sum() == 0)]
#       2 div_feature_matrix = div_feature_matrix.loc[:,(div_feature_matrix.var() > 0)]
# ----> 3 dive_feature_matrix
#
# NameError: name 'dive_feature_matrix' is not defined
